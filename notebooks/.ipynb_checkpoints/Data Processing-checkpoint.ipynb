# %% [markdown]
# # Info
#
# This notebook performs data processing to have a dataset which is comfortable to work with

# %% [markdown]
# # Imports & Magics

# %%
# %matplotlib inline
from utils.setup import *

# %%
X_train = pd.read_csv(TRAIN_INPUT_RAW)
y_train = pd.read_csv(TRAIN_OUTPUT_RAW)
test = pd.read_csv(TEST_INPUT_RAW)

# %%
y_train['RES1_BASE'].plot()

# %%
X_train['Injection RTE (W)'].plot()

# %% [markdown]
# # Merging

# %% [markdown]
# The training data Enedis provides are split in two parts, I prefer to merge them.

# %%
X_train.head()
# Out:
#    IDS      Horodate_UTC                   Horodate  Mois  Injection RTE (W)  \
# 0    1  13/10/2013 22:00  2013-10-13T00:00:00+02:00    10        39784230000
# 1    2  13/10/2013 22:30  2013-10-13T00:30:00+02:00    10        37114681000
# 2    3  13/10/2013 23:00  2013-10-13T01:00:00+02:00    10        36148675000
# 3    4  13/10/2013 23:30  2013-10-13T01:30:00+02:00    10        35488831000
# 4    5  14/10/2013 00:00  2013-10-13T02:00:00+02:00    10        34882911000
#
#    Refoulement RTE (W)  Pertes modélisées (W)  Consommations totale (W)  \
# 0            103415000             2849582877               37576289504
# 1            119543000             2603906116               35230706411
# 2            136447000             2516689035               34428316838
# 3            164083000             2457628530               33922151279
# 4            191859000             2403762298               33447730318
#
#    Consommation HTA télérelevée à courbe de charge (W)  \
# 0                                         8062590100
# 1                                         8023402840
# 2                                         7982839990
# 3                                         7953531370
# 4                                         7922448360
#
#    Consommation totale profilée (W)  Consommation HTA profilée (W)  \
# 0                       29513699404                     1009515939
# 1                       27207303571                     1007708541
# 2                       26445476848                      966660739
# 3                       25968619909                      929311479
# 4                       25525281958                      907509517
#
#    Consommation PME-PMI profilée (W)  \
# 0                         2924365887
# 1                         2881297990
# 2                         2790724292
# 3                         2653092678
# 4                         2641317515
#
#    Consommation professionnelle profilée (W)  \
# 0                                 4819516366
# 1                                 4765108695
# 2                                 4500901592
# 3                                 4308193617
# 4                                 4166651481
#
#    Consommation résidentielle profilée (W)  \
# 0                              20760301211
# 1                              18553188344
# 2                              18187190226
# 3                              18078022135
# 4                              17809803445
#
#    Production décentralisée totale (W)  \
# 0                           1181480681
# 1                           1247399186
# 2                           1331017863
# 3                           1435603490
# 4                           1527593647
#
#    Production décentralisée télérelevée à courbe de charge (W)  \
# 0                                         1169604460
# 1                                         1235680180
# 2                                         1319275090
# 3                                         1423884480
# 4                                         1515861840
#
#    Production décentralisée profilée (W)  \
# 0                               11876221
# 1                               11719006
# 2                               11742773
# 3                               11719010
# 4                               11731807
#
#    Production photovoltaïque profilée (W)  Production autre profilée (W)  \
# 0                                     0.0                       608873.0
# 1                                     0.0                       608873.0
# 2                                     0.0                       608873.0
# 3                                     0.0                       608873.0
# 4                                     0.0                       608873.0
#
#    Température réalisée lissée (°Celcius)  \
# 0                                     9.6
# 1                                     9.6
# 2                                     9.6
# 3                                     9.5
# 4                                     9.5
#
#    Température normale lissée (°Celcius)  Production éolienne totale (W)  \
# 0                                   13.5                     302936853.0
# 1                                   13.5                     368725682.0
# 2                                   13.5                     448572685.0
# 3                                   13.5                     550243295.0
# 4                                   13.5                     644783673.0
#
#    Production photovoltaïque totale (W)  Pseudo rayonnement  \
# 0                               19660.0                 NaN
# 1                               17004.0                 NaN
# 2                               24299.0                 NaN
# 3                               23308.0                 NaN
# 4                               21963.0                 NaN
#
#    Consommation HTA totale (W)  Soutirage net vers autres GRD (W)
# 0                   9072106039                          436423300
# 1                   9031111381                          407924660
# 2                   8949500729                          398239990
# 3                   8882842849                          380571680
# 4                   8829957877                          367153030

# %%
y_train.head()
# Out:
#    IDS      Horodate_UTC                   Horodate  Mois  RES1_BASE  \
# 0    1  13/10/2013 22:00  2013-10-13T00:00:00+02:00    10   0.791405
# 1    2  13/10/2013 22:30  2013-10-13T00:30:00+02:00    10   0.693700
# 2    3  13/10/2013 23:00  2013-10-13T01:00:00+02:00    10   0.648565
# 3    4  13/10/2013 23:30  2013-10-13T01:30:00+02:00    10   0.621059
# 4    5  14/10/2013 00:00  2013-10-13T02:00:00+02:00    10   0.612245
#
#    RES11_BASE  PRO1_BASE   RES2_HC   RES2_HP  PRO2_HC  PRO2_HP
# 0    0.698925        NaN  2.780413  0.346364      NaN      NaN
# 1    0.722778        NaN  2.301527  0.375439      NaN      NaN
# 2    0.678717        NaN  2.361320  0.268125      NaN      NaN
# 3    0.668509        NaN  2.567490  0.192953      NaN      NaN
# 4    0.700487        NaN  2.563460  0.075701      NaN      NaN

# %%
y_train.drop(['Horodate_UTC', 'Horodate', 'Mois'],inplace=True,axis=1)
train = pd.merge(X_train, y_train, on=['IDS', 'IDS'])

# %% [markdown]
# # Temperature

# %% [markdown]
# Converting temperature from celcius to kelvin to avoid having negative values

# %%
train['Température normale lissée (°Celcius)'] = train['Température normale lissée (°Celcius)'].apply(lambda x: x+273.15)
train['Température réalisée lissée (°Celcius)'] = train['Température réalisée lissée (°Celcius)'].apply(lambda x: x+273.15)
train = train.rename(columns={'Température normale lissée (°Celcius)': 'Température normale lissée (°K)', 'Température réalisée lissée (°Celcius)': 'Température réalisée lissée (°K)'})

# %%
test['Température normale lissée (°Celcius)'] = test['Température normale lissée (°Celcius)'].apply(lambda x: x+273.15)
test['Température réalisée lissée (°Celcius)'] = test['Température réalisée lissée (°Celcius)'].apply(lambda x: x+273.15)
test = test.rename(columns={'Température normale lissée (°Celcius)': 'Température normale lissée (°K)', 'Température réalisée lissée (°Celcius)': 'Température réalisée lissée (°K)'})

# %% [markdown]
# # Horodate

# %% [markdown]
# In order to do Time Series, I use Horodate as my dataframe index. I will use the "dd/mm/yyyy hh:mm" date format and use the french timezone for a better understanding of the problem. I drop month and horodate_utc columns as we don't need them.

# %%
train.drop(['Horodate_UTC','Mois'], axis=1, inplace=True)
train['Horodate'] = train['Horodate'].apply(lambda x : pd.to_datetime(date_parser(x).strftime("%d/%m/%Y %H:%M")))
train.set_index('Horodate', drop=True, inplace=True)

# %%
test.drop(['Horodate_UTC','Mois'], axis=1, inplace=True)
test['Horodate'] = test['Horodate'].apply(lambda x: pd.to_datetime(date_parser(x).strftime("%d/%m/%Y %H:%M")))
test.set_index('Horodate', drop=True, inplace=True)

# %% [markdown]
# # Export

# %%
train.head()
# Out:
#                      IDS  Injection RTE (W)  Refoulement RTE (W)  \
# Horodate
# 2013-10-13 00:00:00    1        39784230000            103415000
#
#                      Production autre profilée (W)  \
# Horodate
# 2013-10-13 00:00:00                       608873.0
# 2013-10-13 00:30:00                       608873.0
# 2013-10-13 01:00:00                       608873.0
# 2013-10-13 01:30:00                       608873.0
# 2013-10-13 02:00:00                       608873.0
#
#                      Température réalisée lissée (°K)  \
# Horodate
# 2013-10-13 00:00:00                            282.75
# 2013-10-13 00:30:00                            282.75
# 2013-10-13 01:00:00                            282.75
# 2013-10-13 01:30:00                            282.65
# 2013-10-13 02:00:00                            282.65
#
#                      Température normale lissée (°K)  \
# Horodate
# 2013-10-13 00:00:00                           286.65
# 2013-10-13 00:30:00                           286.65
# 2013-10-13 01:00:00                           286.65
# 2013-10-13 01:30:00                           286.65
# 2013-10-13 02:00:00                           286.65
#
#                      Production éolienne totale (W)  \
# Horodate
# 2013-10-13 00:00:00                     302936853.0
# 2013-10-13 00:30:00                     368725682.0
# 2013-10-13 01:00:00                     448572685.0
# 2013-10-13 01:30:00                     550243295.0
# 2013-10-13 02:00:00                     644783673.0
#
#                      Production photovoltaïque totale (W)  Pseudo rayonnement  \
# Horodate
# 2013-10-13 00:00:00                               19660.0                 NaN
# 2013-10-13 00:30:00                               17004.0                 NaN
# 2013-10-13 01:00:00                               24299.0                 NaN
# 2013-10-13 01:30:00                               23308.0                 NaN
# 2013-10-13 02:00:00                               21963.0                 NaN
#
#                      Consommation HTA totale (W)  \
# Horodate
# 2013-10-13 00:00:00                   9072106039
# 2013-10-13 00:30:00                   9031111381
# 2013-10-13 01:00:00                   8949500729
# 2013-10-13 01:30:00                   8882842849
# 2013-10-13 02:00:00                   8829957877
#
#                      Soutirage net vers autres GRD (W)  RES1_BASE  RES11_BASE  \
# Horodate
# 2013-10-13 00:00:00                          436423300   0.791405    0.698925
# 2013-10-13 00:30:00                          407924660   0.693700    0.722778
# 2013-10-13 01:00:00                          398239990   0.648565    0.678717
# 2013-10-13 01:30:00                          380571680   0.621059    0.668509
# 2013-10-13 02:00:00                          367153030   0.612245    0.700487
#
#                      PRO1_BASE   RES2_HC   RES2_HP  PRO2_HC  PRO2_HP
# Horodate
# 2013-10-13 00:00:00        NaN  2.780413  0.346364      NaN      NaN
# 2013-10-13 00:30:00        NaN  2.301527  0.375439      NaN      NaN
# 2013-10-13 01:00:00        NaN  2.361320  0.268125      NaN      NaN
# 2013-10-13 01:30:00        NaN  2.567490  0.192953      NaN      NaN
# 2013-10-13 02:00:00        NaN  2.563460  0.075701      NaN      NaN

# %%
test.head()
# Out:
#                        IDS  Injection RTE (W)  Refoulement RTE (W)  \
# Horodate
# 2017-01-07 00:00:00  65137        32081381000           1176090000
# 2017-01-07 00:30:00  65138        29070230000           1238080000
# 2017-01-07 01:00:00  65139        28002107000           1297531000
# 2017-01-07 01:30:00  65140        27269022000           1297289000
# 2017-01-07 02:00:00  65141        26728684000           1343579000
#
#                      Pertes modélisées (W)  Consommations totale (W)  \
# Horodate
# 2017-01-07 00:00:00             2272879128               31951824749
# 2017-01-07 00:30:00             2014931240               29144410398
# 2017-01-07 01:00:00             1924960686               28135803907
# 2017-01-07 01:30:00             1863674658               27479471861
# 2017-01-07 02:00:00             1818743827               26994332505
#
# 2017-01-07 00:00:00                           293.15
# 2017-01-07 00:30:00                           293.15
# 2017-01-07 01:00:00                           293.15
# 2017-01-07 01:30:00                           293.05
# 2017-01-07 02:00:00                           293.05
#
#                      Production éolienne totale (W)  \
# Horodate
# 2017-01-07 00:00:00                      2490058667
# 2017-01-07 00:30:00                      2470877000
# 2017-01-07 01:00:00                      2482582333
# 2017-01-07 01:30:00                      2477928333
# 2017-01-07 02:00:00                      2517481333
#
#                      Production photovoltaïque totale (W)  Pseudo rayonnement  \
# Horodate
# 2017-01-07 00:00:00                                 27667                  32
# 2017-01-07 00:30:00                                 27667                  33
# 2017-01-07 01:00:00                                 28000                  33
# 2017-01-07 01:30:00                                 26333                  33
# 2017-01-07 02:00:00                                 28333                  34
#
#                      Consommation HTA totale (W)  \
# Horodate
# 2017-01-07 00:00:00                  11106008154
# 2017-01-07 00:30:00                  10990628629
# 2017-01-07 01:00:00                  10767164038
# 2017-01-07 01:30:00                  10619184135
# 2017-01-07 02:00:00                  10473951266
#
#                      Soutirage net vers autres GRD (W)
# Horodate
# 2017-01-07 00:00:00                          311603934
# 2017-01-07 00:30:00                          284388050
# 2017-01-07 01:00:00                          272223000
# 2017-01-07 01:30:00                          256587183
# 2017-01-07 02:00:00                          246899584

# %%
test['Injection RTE (W)'].plot()

# %%
train[['RES1_BASE','RES11_BASE']].join(test,how='outer').index
# Out:
# DatetimeIndex(['2013-01-11 00:00:00', '2013-01-11 00:30:00',
#                '2013-01-11 01:00:00', '2013-01-11 01:30:00',
#                '2013-01-11 02:00:00', '2013-01-11 02:30:00',
#                '2013-01-11 03:00:00', '2013-01-11 03:30:00',
#                '2013-01-11 04:00:00', '2013-01-11 04:30:00',
#                ...
#                '2018-12-10 19:00:00', '2018-12-10 19:30:00',
#                '2018-12-10 20:00:00', '2018-12-10 20:30:00',
#                '2018-12-10 21:00:00', '2018-12-10 21:30:00',
#                '2018-12-10 22:00:00', '2018-12-10 22:30:00',
#                '2018-12-10 23:00:00', '2018-12-10 23:30:00'],
#               dtype='datetime64[ns]', name='Horodate', length=87648, freq=None)

# %%
pd.date_range(start='2013-01-11 00:00',end='2018-06-30 23:30',freq="30min")
# Out:
# DatetimeIndex(['2013-01-11 00:00:00', '2013-01-11 00:30:00',
#                '2013-01-11 01:00:00', '2013-01-11 01:30:00',
#                '2013-01-11 02:00:00', '2013-01-11 02:30:00',
#                '2013-01-11 03:00:00', '2013-01-11 03:30:00',
#                '2013-01-11 04:00:00', '2013-01-11 04:30:00',
#                ...
#                '2018-06-30 19:00:00', '2018-06-30 19:30:00',
#                '2018-06-30 20:00:00', '2018-06-30 20:30:00',
#                '2018-06-30 21:00:00', '2018-06-30 21:30:00',
#                '2018-06-30 22:00:00', '2018-06-30 22:30:00',
#                '2018-06-30 23:00:00', '2018-06-30 23:30:00'],
#               dtype='datetime64[ns]', length=95856, freq='30T')

# %%
dt_range = pd.date_range(start='2013-10-13 00:00',end='2018-12-10 23:30',freq="30min")
dt_df = pd.DataFrame(index=dt_range)

# %%
miss = dt_df.join(train.sort_index(), how='outer')

# %%
pd.DataFrame.to_csv(train, TRAIN_MERGED)
pd.DataFrame.to_csv(test, TEST_MERGED)
